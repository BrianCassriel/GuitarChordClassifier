# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten

# Mount drive
from google.colab import drive
drive.mount('/content/drive/')

# Path to your dataset
dataset1_path = '/content/drive/MyDrive/guitar-dataset/IDMT-SMT-GUITAR_V2/dataset1'
print("Contents of", dataset1_path)
print(os.listdir(dataset1_path))

# Load audio dataset UNBATCHED
train_dataset, test_dataset = tf.keras.utils.audio_dataset_from_directory(
    directory=dataset1_path,
    batch_size=None,  # <-- IMPORTANT
    validation_split=0.2,
    seed=0,
    output_sequence_length=16000,
    subset='both'
)

# Inspect example
for audio, label in train_dataset.take(1):
    print("Raw audio shape:", audio.shape)   # should be (16000, 1)
    print("Label:", label.numpy())
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# Contents of /content/drive/MyDrive/guitar-dataset/IDMT-SMT-GUITAR_V2/dataset1
# ['Ibanez Power Strat Clean Bridge HU', 'Ibanez Power Strat Clean Neck HU', 'Ibanez Power Strat Clean Bridge HU Chords', 'Fender Strat Clean Neck SC Chords', 'Ibanez Power Strat Clean Bridge+Neck SC', 'Fender Strat Clean Neck SC']
# Found 400 files belonging to 6 classes.
# Using 320 files for training.
# Using 80 files for validation.
# Raw audio shape: (16000, 1)
# Label: 3

# %%
import os
import re
import shutil

# Source: original dataset1 (instrument / pickup folders etc.)
src_root = "/content/drive/MyDrive/guitar-dataset/IDMT-SMT-GUITAR_V2/dataset1"

# Destination: new dataset grouped by chord label
dst_root = "/content/drive/MyDrive/guitar-dataset/chords_by_label"
os.makedirs(dst_root, exist_ok=True)

print("Source root:", src_root)
print("Destination root:", dst_root)
# Out:
# Source root: /content/drive/MyDrive/guitar-dataset/IDMT-SMT-GUITAR_V2/dataset1
# Destination root: /content/drive/MyDrive/guitar-dataset/chords_by_label

# %%
def get_chord_label_from_filename(filename: str) -> str | None:
    """
    Extract chord label from filenames like:
    '1-E1-Major 00.wav', '2-E1-Minor 01.wav', '3-A2-Major 06.wav'

    Returns labels like: 'E_major', 'A_minor', etc.
    """
    # Remove extension
    base = os.path.splitext(filename)[0]   # e.g. '1-E1-Major 00'

    # Take just the part before the space: '1-E1-Major'
    first_part = base.split(" ")[0]

    # Pattern: <index>-<Note><something>-<Major|Minor>
    # Example: 1-E1-Major  → groups: 'E1', 'Major'
    m = re.match(r"^\d+-([A-G][b#]?\d*)-(Major|Minor)", first_part)
    if not m:
        return None

    note_token = m.group(1)   # 'E1', 'A2', etc.
    quality = m.group(2)      # 'Major' or 'Minor'

    # Root note: letter + optional accidental, ignore trailing digit(s)
    m_note = re.match(r"^([A-G][b#]?)", note_token)
    if not m_note:
        return None

    root = m_note.group(1)  # 'E', 'A', 'Eb', 'F#', ...
    label = f"{root}_{quality.lower()}"   # e.g. 'E_major'
    return label

# Quick sanity check
test_names = [
    "1-E1-Major 00.wav",
    "2-E1-Minor 07.wav",
    "3-A2-Major 06.wav",
]

for name in test_names:
    print(name, "→", get_chord_label_from_filename(name))
# Out:
# 1-E1-Major 00.wav → E_major
# 2-E1-Minor 07.wav → E_minor
# 3-A2-Major 06.wav → A_major

# %%
#THIS CODE PUTS CHORDS INTO FOLDERS
copied_count = 0
skipped_count = 0

for dirpath, dirnames, filenames in os.walk(src_root):
    # Only look inside 'audio' folders
    if os.path.basename(dirpath).lower() != "audio":
        continue

    print("Scanning:", dirpath)
    for fname in filenames:
        if not fname.lower().endswith(".wav"):
            continue

        chord_label = get_chord_label_from_filename(fname)
        if chord_label is None:
            print("  [SKIP] Could not parse chord from:", fname)
            skipped_count += 1
            continue

        # Make destination folder for this chord
        dst_dir = os.path.join(dst_root, chord_label)
        os.makedirs(dst_dir, exist_ok=True)

        src_path = os.path.join(dirpath, fname)
        dst_path = os.path.join(dst_dir, fname)

        # Copy file (use copy2 to preserve metadata)
        shutil.copy2(src_path, dst_path)
        copied_count += 1

print("\nDone.")
print("Copied:", copied_count, "files")
print("Skipped (no chord parsed):", skipped_count)
# Out:
# Scanning: /content/drive/MyDrive/guitar-dataset/IDMT-SMT-GUITAR_V2/dataset1/Ibanez Power Strat Clean Bridge HU/audio
#   [SKIP] Could not parse chord from: G53-49204-1111-252.wav
#   [SKIP] Could not parse chord from: G53-45200-1111-248.wav
#   [SKIP] Could not parse chord from: G53-48203-1111-251.wav
#   [SKIP] Could not parse chord from: G53-47202-1111-250.wav
#   [SKIP] Could not parse chord from: G53-46201-1111-249.wav
#   [SKIP] Could not parse chord from: G53-51206-1111-254.wav
#   [SKIP] Could not parse chord from: G53-54209-1111-257.wav
#   [SKIP] Could not parse chord from: G53-61502-1111-289.wav
#   [SKIP] Could not parse chord from: G53-57212-1111-260.wav
#   [SKIP] Could not parse chord from: G53-68509-1111-296.wav
#   [SKIP] Could not parse chord from: G53-60501-1111-288.wav
#   [SKIP] Could not parse chord from: G53-62503-1111-290.wav
#   [SKIP] Could not parse chord from: G53-52207-1111-255.wav
#   [SKIP] Could not parse chord from: G53-50205-1111-253.wav
#   [SKIP] Could not parse chord from: G53-55210-1111-258.wav
#   [SKIP] Could not parse chord from: G53-66507-1111-294.wav
#   [SKIP] Could not parse chord from: G53-56211-1111-259.wav
#   [SKIP] Could not parse chord from: G53-53208-1111-256.wav
#   [SKIP] Could not parse chord from: G53-59500-1111-287.wav
#   [SKIP] Could not parse chord from: G53-63504-1111-291.wav
#   [SKIP] Could not parse chord from: G53-64505-1111-292.wav
#   [SKIP] Could not parse chord from: G53-65506-1111-293.wav
#   [SKIP] Could not parse chord from: G53-67508-1111-295.wav
#   [SKIP] Could not parse chord from: G53-69510-1111-297.wav
#   [SKIP] Could not parse chord from: G53-50300-1111-261.wav
#   [SKIP] Could not parse chord from: G53-51301-1111-262.wav
#   [SKIP] Could not parse chord from: G53-70511-1111-298.wav
#   [SKIP] Could not parse chord from: G53-71512-1111-299.wav
#   [SKIP] Could not parse chord from: G53-57307-1111-268.wav
#   [SKIP] Could not parse chord from: G53-62312-1111-273.wav
#   [SKIP] Could not parse chord from: G53-59309-1111-270.wav
#   [SKIP] Could not parse chord from: G53-55305-1111-266.wav
#   [SKIP] Could not parse chord from: G53-60310-1111-271.wav
#   [SKIP] Could not parse chord from: G53-52302-1111-263.wav
#   [SKIP] Could not parse chord from: G53-56306-1111-267.wav
#   [SKIP] Could not parse chord from: G53-66602-1111-302.wav
#   [SKIP] Could not parse chord from: G53-53303-1111-264.wav
#   [SKIP] Could not parse chord from: G53-64600-1111-300.wav
#   [SKIP] Could not parse chord from: G53-54304-1111-265.wav
#   [SKIP] Could not parse chord from: G53-61311-1111-272.wav
#   [SKIP] Could not parse chord from: G53-65601-1111-301.wav
#   [SKIP] Could not parse chord from: G53-58308-1111-269.wav
#   [SKIP] Could not parse chord from: G53-68604-1111-304.wav
#   [SKIP] Could not parse chord from: G53-67603-1111-303.wav
#   [SKIP] Could not parse chord from: G53-72608-1111-308.wav
#   [SKIP] Could not parse chord from: G53-46106-1111-241.wav
#   [SKIP] Could not parse chord from: G53-71607-1111-307.wav
#   [SKIP] Could not parse chord from: G53-42102-1111-237.wav
#   [SKIP] Could not parse chord from: G53-74610-1111-310.wav
#   [SKIP] Could not parse chord from: G53-75611-1111-311.wav
#   [SKIP] Could not parse chord from: G53-41101-1111-236.wav
#   [SKIP] Could not parse chord from: G53-76612-1111-312.wav
#   [SKIP] Could not parse chord from: G53-45105-1111-240.wav
#   [SKIP] Could not parse chord from: G53-73609-1111-309.wav
#   [SKIP] Could not parse chord from: G53-44104-1111-239.wav
#   [SKIP] Could not parse chord from: G53-40100-1111-235.wav
#   [SKIP] Could not parse chord from: G53-69605-1111-305.wav
#   [SKIP] Could not parse chord from: G53-70606-1111-306.wav
#   [SKIP] Could not parse chord from: G53-49109-1111-244.wav
#   [SKIP] Could not parse chord from: G53-62407-1111-281.wav
#   [SKIP] Could not parse chord from: G53-59404-1111-278.wav
#   [SKIP] Could not parse chord from: G53-51111-1111-246.wav
#   [SKIP] Could not parse chord from: G53-63408-1111-282.wav
#   [SKIP] Could not parse chord from: G53-66411-1111-285.wav
#   [SKIP] Could not parse chord from: G53-55400-1111-274.wav
#   [SKIP] Could not parse chord from: G53-67412-1111-286.wav
#   [SKIP] Could not parse chord from: G53-52112-1111-247.wav
#   [SKIP] Could not parse chord from: G53-61406-1111-280.wav
#   [SKIP] Could not parse chord from: G53-56401-1111-275.wav
#   [SKIP] Could not parse chord from: G53-65410-1111-284.wav
#   [SKIP] Could not parse chord from: G53-48108-1111-243.wav
#   [SKIP] Could not parse chord from: G53-57402-1111-276.wav
#   [SKIP] Could not parse chord from: G53-64409-1111-283.wav
#   [SKIP] Could not parse chord from: G53-60405-1111-279.wav
#   [SKIP] Could not parse chord from: G53-50110-1111-245.wav
#   [SKIP] Could not parse chord from: G53-58403-1111-277.wav
#   [SKIP] Could not parse chord from: G53-47107-1111-242.wav
#   [SKIP] Could not parse chord from: G53-43103-1111-238.wav
# Scanning: /content/drive/MyDrive/guitar-dataset/IDMT-SMT-GUITAR_V2/dataset1/Ibanez Power Strat Clean Neck HU/audio
#   [SKIP] Could not parse chord from: G53-64600-1111-00144.wav
#   [SKIP] Could not parse chord from: G53-60501-1111-00132.wav
#   [SKIP] Could not parse chord from: G53-68509-1111-00140.wav
#   [SKIP] Could not parse chord from: G53-73609-1111-00153.wav
#   [SKIP] Could not parse chord from: G53-75611-1111-00155.wav
#   [SKIP] Could not parse chord from: G53-59500-1111-00131.wav
#   [SKIP] Could not parse chord from: G53-72608-1111-00152.wav
#   [SKIP] Could not parse chord from: G53-68604-1111-00148.wav
#   [SKIP] Could not parse chord from: G53-67508-1111-00139.wav
#   [SKIP] Could not parse chord from: G53-65601-1111-00145.wav
#   [SKIP] Could not parse chord from: G53-63504-1111-00135.wav
#   [SKIP] Could not parse chord from: G53-66507-1111-00138.wav
#   [SKIP] Could not parse chord from: G53-67603-1111-00147.wav
#   [SKIP] Could not parse chord from: G53-61502-1111-00133.wav
#   [SKIP] Could not parse chord from: G53-71607-1111-00151.wav
#   [SKIP] Could not parse chord from: G53-66602-1111-00146.wav
#   [SKIP] Could not parse chord from: G53-70606-1111-00150.wav
#   [SKIP] Could not parse chord from: G53-65506-1111-00137.wav
#   [SKIP] Could not parse chord from: G53-62503-1111-00134.wav
#   [SKIP] Could not parse chord from: G53-69605-1111-00149.wav
#   [SKIP] Could not parse chord from: G53-74610-1111-00154.wav
#   [SKIP] Could not parse chord from: G53-64505-1111-00136.wav
#   [SKIP] Could not parse chord from: G53-76612-1111-00156.wav
#   [SKIP] Could not parse chord from: G53-61406-1111-00124.wav
#   [SKIP] Could not parse chord from: G53-50300-1111-00105.wav
#   [SKIP] Could not parse chord from: G53-66411-1111-00129.wav
#   [SKIP] Could not parse chord from: G53-71512-1111-00143.wav
#   [SKIP] Could not parse chord from: G53-55400-1111-00118.wav
#   [SKIP] Could not parse chord from: G53-58403-1111-00121.wav
#   [SKIP] Could not parse chord from: G53-64409-1111-00127.wav
#   [SKIP] Could not parse chord from: G53-62407-1111-00125.wav
#   [SKIP] Could not parse chord from: G53-63408-1111-00126.wav
#   [SKIP] Could not parse chord from: G53-57402-1111-00120.wav
#   [SKIP] Could not parse chord from: G53-70511-1111-00142.wav
#   [SKIP] Could not parse chord from: G53-59404-1111-00122.wav
#   [SKIP] Could not parse chord from: G53-69510-1111-00141.wav
#   [SKIP] Could not parse chord from: G53-56401-1111-00119.wav
#   [SKIP] Could not parse chord from: G53-65410-1111-00128.wav
#   [SKIP] Could not parse chord from: G53-67412-1111-00130.wav
#   [SKIP] Could not parse chord from: G53-60405-1111-00123.wav
#   [SKIP] Could not parse chord from: G53-60310-1111-00115.wav
#   [SKIP] Could not parse chord from: G53-46201-1111-00093.wav
#   [SKIP] Could not parse chord from: G53-58308-1111-00113.wav
#   [SKIP] Could not parse chord from: G53-47202-1111-00094.wav
#   [SKIP] Could not parse chord from: G53-56306-1111-00111.wav
#   [SKIP] Could not parse chord from: G53-62312-1111-00117.wav
#   [SKIP] Could not parse chord from: G53-55305-1111-00110.wav
#   [SKIP] Could not parse chord from: G53-51301-1111-00106.wav
#   [SKIP] Could not parse chord from: G53-57307-1111-00112.wav
#   [SKIP] Could not parse chord from: G53-49204-1111-00096.wav
#   [SKIP] Could not parse chord from: G53-48203-1111-00095.wav
#   [SKIP] Could not parse chord from: G53-54304-1111-00109.wav
#   [SKIP] Could not parse chord from: G53-45200-1111-00092.wav
#   [SKIP] Could not parse chord from: G53-61311-1111-00116.wav
#   [SKIP] Could not parse chord from: G53-53303-1111-00108.wav
#   [SKIP] Could not parse chord from: G53-52302-1111-00107.wav
#   [SKIP] Could not parse chord from: G53-59309-1111-00114.wav
#   [SKIP] Could not parse chord from: G53-52207-1111-00099.wav
#   [SKIP] Could not parse chord from: G53-53208-1111-00100.wav
#   [SKIP] Could not parse chord from: G53-51206-1111-00098.wav
#   [SKIP] Could not parse chord from: G53-45105-1111-00084.wav
#   [SKIP] Could not parse chord from: G53-57212-1111-00104.wav
#   [SKIP] Could not parse chord from: G53-42102-1111-00081.wav
#   [SKIP] Could not parse chord from: G53-44104-1111-00083.wav
#   [SKIP] Could not parse chord from: G53-50205-1111-00097.wav
#   [SKIP] Could not parse chord from: G53-56211-1111-00103.wav
#   [SKIP] Could not parse chord from: G53-55210-1111-00102.wav
#   [SKIP] Could not parse chord from: G53-40100-1111-00079.wav
#   [SKIP] Could not parse chord from: G53-51111-1111-00090.wav
#   [SKIP] Could not parse chord from: G53-43103-1111-00082.wav
#   [SKIP] Could not parse chord from: G53-41101-1111-00080.wav
#   [SKIP] Could not parse chord from: G53-49109-1111-00088.wav
#   [SKIP] Could not parse chord from: G53-46106-1111-00085.wav
#   [SKIP] Could not parse chord from: G53-50110-1111-00089.wav
#   [SKIP] Could not parse chord from: G53-48108-1111-00087.wav
#   [SKIP] Could not parse chord from: G53-54209-1111-00101.wav
#   [SKIP] Could not parse chord from: G53-47107-1111-00086.wav
#   [SKIP] Could not parse chord from: G53-52112-1111-00091.wav
# Scanning: /content/drive/MyDrive/guitar-dataset/IDMT-SMT-GUITAR_V2/dataset1/Ibanez Power Strat Clean Bridge HU Chords/audio
# Scanning: /content/drive/MyDrive/guitar-dataset/IDMT-SMT-GUITAR_V2/dataset1/Fender Strat Clean Neck SC Chords/audio
# Scanning: /content/drive/MyDrive/guitar-dataset/IDMT-SMT-GUITAR_V2/dataset1/Ibanez Power Strat Clean Bridge+Neck SC/audio
#   [SKIP] Could not parse chord from: G53-46106-1111-163.wav
#   [SKIP] Could not parse chord from: G53-50205-1111-175.wav
#   [SKIP] Could not parse chord from: G53-51111-1111-168.wav
#   [SKIP] Could not parse chord from: G53-43103-1111-160.wav
#   [SKIP] Could not parse chord from: G53-45105-1111-162.wav
#   [SKIP] Could not parse chord from: G53-41101-1111-158.wav
#   [SKIP] Could not parse chord from: G53-51206-1111-176.wav
#   [SKIP] Could not parse chord from: G53-52112-1111-169.wav
#   [SKIP] Could not parse chord from: G53-48108-1111-165.wav
#   [SKIP] Could not parse chord from: G53-45200-1111-170.wav
#   [SKIP] Could not parse chord from: G53-47107-1111-164.wav
#   [SKIP] Could not parse chord from: G53-49109-1111-166.wav
#   [SKIP] Could not parse chord from: G53-48203-1111-173.wav
#   [SKIP] Could not parse chord from: G53-47202-1111-172.wav
#   [SKIP] Could not parse chord from: G53-40100-1111-157.wav
#   [SKIP] Could not parse chord from: G53-42102-1111-159.wav
#   [SKIP] Could not parse chord from: G53-50110-1111-167.wav
#   [SKIP] Could not parse chord from: G53-46201-1111-171.wav
#   [SKIP] Could not parse chord from: G53-49204-1111-174.wav
#   [SKIP] Could not parse chord from: G53-44104-1111-161.wav
#   [SKIP] Could not parse chord from: G53-66602-1111-224.wav
#   [SKIP] Could not parse chord from: G53-59500-1111-209.wav
#   [SKIP] Could not parse chord from: G53-57402-1111-198.wav
#   [SKIP] Could not parse chord from: G53-68509-1111-218.wav
#   [SKIP] Could not parse chord from: G53-68604-1111-226.wav
#   [SKIP] Could not parse chord from: G53-72608-1111-230.wav
#   [SKIP] Could not parse chord from: G53-53303-1111-186.wav
#   [SKIP] Could not parse chord from: G53-58403-1111-199.wav
#   [SKIP] Could not parse chord from: G53-52207-1111-177.wav
#   [SKIP] Could not parse chord from: G53-60405-1111-201.wav
#   [SKIP] Could not parse chord from: G53-57212-1111-182.wav
#   [SKIP] Could not parse chord from: G53-56211-1111-181.wav
#   [SKIP] Could not parse chord from: G53-74610-1111-232.wav
#   [SKIP] Could not parse chord from: G53-63408-1111-204.wav
#   [SKIP] Could not parse chord from: G53-55400-1111-196.wav
#   [SKIP] Could not parse chord from: G53-69605-1111-227.wav
#   [SKIP] Could not parse chord from: G53-62312-1111-195.wav
#   [SKIP] Could not parse chord from: G53-63504-1111-213.wav
#   [SKIP] Could not parse chord from: G53-59404-1111-200.wav
#   [SKIP] Could not parse chord from: G53-61406-1111-202.wav
#   [SKIP] Could not parse chord from: G53-64505-1111-214.wav
#   [SKIP] Could not parse chord from: G53-73609-1111-231.wav
#   [SKIP] Could not parse chord from: G53-58308-1111-191.wav
#   [SKIP] Could not parse chord from: G53-75611-1111-233.wav
#   [SKIP] Could not parse chord from: G53-56401-1111-197.wav
#   [SKIP] Could not parse chord from: G53-71512-1111-221.wav
#   [SKIP] Could not parse chord from: G53-54304-1111-187.wav
#   [SKIP] Could not parse chord from: G53-62407-1111-203.wav
#   [SKIP] Could not parse chord from: G53-70606-1111-228.wav
#   [SKIP] Could not parse chord from: G53-61311-1111-194.wav
#   [SKIP] Could not parse chord from: G53-66411-1111-207.wav
#   [SKIP] Could not parse chord from: G53-60310-1111-193.wav
#   [SKIP] Could not parse chord from: G53-52302-1111-185.wav
#   [SKIP] Could not parse chord from: G53-65410-1111-206.wav
#   [SKIP] Could not parse chord from: G53-65506-1111-215.wav
#   [SKIP] Could not parse chord from: G53-67412-1111-208.wav
#   [SKIP] Could not parse chord from: G53-67508-1111-217.wav
#   [SKIP] Could not parse chord from: G53-60501-1111-210.wav
#   [SKIP] Could not parse chord from: G53-67603-1111-225.wav
#   [SKIP] Could not parse chord from: G53-53208-1111-178.wav
#   [SKIP] Could not parse chord from: G53-65601-1111-223.wav
#   [SKIP] Could not parse chord from: G53-56306-1111-189.wav
#   [SKIP] Could not parse chord from: G53-55305-1111-188.wav
#   [SKIP] Could not parse chord from: G53-51301-1111-184.wav
#   [SKIP] Could not parse chord from: G53-64409-1111-205.wav
#   [SKIP] Could not parse chord from: G53-66507-1111-216.wav
#   [SKIP] Could not parse chord from: G53-64600-1111-222.wav
#   [SKIP] Could not parse chord from: G53-59309-1111-192.wav
#   [SKIP] Could not parse chord from: G53-71607-1111-229.wav
#   [SKIP] Could not parse chord from: G53-50300-1111-183.wav
#   [SKIP] Could not parse chord from: G53-61502-1111-211.wav
#   [SKIP] Could not parse chord from: G53-69510-1111-219.wav
#   [SKIP] Could not parse chord from: G53-54209-1111-179.wav
#   [SKIP] Could not parse chord from: G53-70511-1111-220.wav
#   [SKIP] Could not parse chord from: G53-57307-1111-190.wav
#   [SKIP] Could not parse chord from: G53-55210-1111-180.wav
#   [SKIP] Could not parse chord from: G53-76612-1111-234.wav
#   [SKIP] Could not parse chord from: G53-62503-1111-212.wav
# Scanning: /content/drive/MyDrive/guitar-dataset/IDMT-SMT-GUITAR_V2/dataset1/Fender Strat Clean Neck SC/audio
#   [SKIP] Could not parse chord from: G53-54209-1111-00023.wav
#   [SKIP] Could not parse chord from: G53-59500-1111-00053.wav
#   [SKIP] Could not parse chord from: G53-60501-1111-00054.wav
#   [SKIP] Could not parse chord from: G53-68509-1111-00062.wav
#   [SKIP] Could not parse chord from: G53-49204-1111-00018.wav
#   [SKIP] Could not parse chord from: G53-56211-1111-00025.wav
#   [SKIP] Could not parse chord from: G53-50205-1111-00019.wav
#   [SKIP] Could not parse chord from: G53-45200-1111-00014.wav
#   [SKIP] Could not parse chord from: G53-51206-1111-00020.wav
#   [SKIP] Could not parse chord from: G53-63504-1111-00057.wav
#   [SKIP] Could not parse chord from: G53-47202-1111-00016.wav
#   [SKIP] Could not parse chord from: G53-57212-1111-00026.wav
#   [SKIP] Could not parse chord from: G53-69510-1111-00063.wav
#   [SKIP] Could not parse chord from: G53-52207-1111-00021.wav
#   [SKIP] Could not parse chord from: G53-71512-1111-00065.wav
#   [SKIP] Could not parse chord from: G53-53208-1111-00022.wav
#   [SKIP] Could not parse chord from: G53-55210-1111-00024.wav
#   [SKIP] Could not parse chord from: G53-70511-1111-00064.wav
#   [SKIP] Could not parse chord from: G53-61502-1111-00055.wav
#   [SKIP] Could not parse chord from: G53-46201-1111-00015.wav
#   [SKIP] Could not parse chord from: G53-62503-1111-00056.wav
#   [SKIP] Could not parse chord from: G53-48203-1111-00017.wav
#   [SKIP] Could not parse chord from: G53-75611-1111-00077.wav
#   [SKIP] Could not parse chord from: G53-57402-1111-00042.wav
#   [SKIP] Could not parse chord from: G53-59309-1111-00036.wav
#   [SKIP] Could not parse chord from: G53-64600-1111-00066.wav
#   [SKIP] Could not parse chord from: G53-71607-1111-00073.wav
#   [SKIP] Could not parse chord from: G53-58308-1111-00035.wav
#   [SKIP] Could not parse chord from: G53-51111-1111-00012.wav
#   [SKIP] Could not parse chord from: G53-64409-1111-00049.wav
#   [SKIP] Could not parse chord from: G53-64505-1111-00058.wav
#   [SKIP] Could not parse chord from: G53-41101-1111-00002.wav
#   [SKIP] Could not parse chord from: G53-62407-1111-00047.wav
#   [SKIP] Could not parse chord from: G53-74610-1111-00076.wav
#   [SKIP] Could not parse chord from: G53-72608-1111-00074.wav
#   [SKIP] Could not parse chord from: G53-61311-1111-00038.wav
#   [SKIP] Could not parse chord from: G53-42102-1111-00003.wav
#   [SKIP] Could not parse chord from: G53-54304-1111-00031.wav
#   [SKIP] Could not parse chord from: G53-67508-1111-00061.wav
#   [SKIP] Could not parse chord from: G53-67603-1111-00069.wav
#   [SKIP] Could not parse chord from: G53-76612-1111-00078.wav
#   [SKIP] Could not parse chord from: G53-67412-1111-00052.wav
#   [SKIP] Could not parse chord from: G53-44104-1111-00005.wav
#   [SKIP] Could not parse chord from: G53-40100-1111-00001.wav
#   [SKIP] Could not parse chord from: G53-53303-1111-00030.wav
#   [SKIP] Could not parse chord from: G53-68604-1111-00070.wav
#   [SKIP] Could not parse chord from: G53-65506-1111-00059.wav
#   [SKIP] Could not parse chord from: G53-46106-1111-00007.wav
#   [SKIP] Could not parse chord from: G53-55400-1111-00040.wav
#   [SKIP] Could not parse chord from: G53-60310-1111-00037.wav
#   [SKIP] Could not parse chord from: G53-56306-1111-00033.wav
#   [SKIP] Could not parse chord from: G53-52112-1111-00013.wav
#   [SKIP] Could not parse chord from: G53-70606-1111-00072.wav
#   [SKIP] Could not parse chord from: G53-55305-1111-00032.wav
#   [SKIP] Could not parse chord from: G53-58403-1111-00043.wav
#   [SKIP] Could not parse chord from: G53-48108-1111-00009.wav
#   [SKIP] Could not parse chord from: G53-66507-1111-00060.wav
#   [SKIP] Could not parse chord from: G53-66411-1111-00051.wav
#   [SKIP] Could not parse chord from: G53-69605-1111-00071.wav
#   [SKIP] Could not parse chord from: G53-59404-1111-00044.wav
#   [SKIP] Could not parse chord from: G53-51301-1111-00028.wav
#   [SKIP] Could not parse chord from: G53-65601-1111-00067.wav
#   [SKIP] Could not parse chord from: G53-73609-1111-00075.wav
#   [SKIP] Could not parse chord from: G53-63408-1111-00048.wav
#   [SKIP] Could not parse chord from: G53-65410-1111-00050.wav
#   [SKIP] Could not parse chord from: G53-50110-1111-00011.wav
#   [SKIP] Could not parse chord from: G53-56401-1111-00041.wav
#   [SKIP] Could not parse chord from: G53-61406-1111-00046.wav
#   [SKIP] Could not parse chord from: G53-57307-1111-00034.wav
#   [SKIP] Could not parse chord from: G53-66602-1111-00068.wav
#   [SKIP] Could not parse chord from: G53-62312-1111-00039.wav
#   [SKIP] Could not parse chord from: G53-52302-1111-00029.wav
#   [SKIP] Could not parse chord from: G53-47107-1111-00008.wav
#   [SKIP] Could not parse chord from: G53-60405-1111-00045.wav
#   [SKIP] Could not parse chord from: G53-45105-1111-00006.wav
#   [SKIP] Could not parse chord from: G53-49109-1111-00010.wav
#   [SKIP] Could not parse chord from: G53-50300-1111-00027.wav
#   [SKIP] Could not parse chord from: G53-43103-1111-00004.wav
#
# Done.
# Copied: 88 files
# Skipped (no chord parsed): 312

# %%
chord_dataset_path = "/content/drive/MyDrive/guitar-dataset/chords_by_label"

train_dataset, test_dataset = tf.keras.utils.audio_dataset_from_directory(
    directory=chord_dataset_path,
    batch_size=None,
    validation_split=0.2,
    seed=0,
    output_sequence_length=16000,
    subset='both'
)

class_names = train_dataset.class_names
print("Chord classes:", class_names)

for audio, label in train_dataset.take(1):
    print("Raw audio shape:", audio.shape)
    print("Label index:", label.numpy())
    print("Label name:", class_names[label.numpy()])
# Out:
# Found 44 files belonging to 4 classes.
# Using 36 files for training.
# Using 8 files for validation.
# Chord classes: ['A_major', 'A_minor', 'E_major', 'E_minor']
# Raw audio shape: (16000, 1)
# Label index: 3
# Label name: E_minor

# %%
for audio, label in train_dataset.take(5):
    print("Audio shape:", audio.shape)   # (16000, 1)
    print("Label:", label.numpy())       # scalar like 0,1,2...
# Out:
# Audio shape: (16000, 1)
# Label: 0
# Audio shape: (16000, 1)
# Label: 0
# Audio shape: (16000, 1)
# Label: 2
# Audio shape: (16000, 1)
# Label: 2
# Audio shape: (16000, 1)
# Label: 1

# %% [markdown]
# ### Create a function to convert audio to spectrograms

# %%
def get_spectrogram(waveform):
    waveform = tf.squeeze(waveform, axis=-1)  # (16000,) from (16000,1)

    spectrogram = tf.signal.stft(
        waveform,
        frame_length=255,
        frame_step=128
    )
    spectrogram = tf.abs(spectrogram)
    spectrogram = spectrogram[..., tf.newaxis]  # add channel dim
    spectrogram = tf.image.resize(spectrogram, [124, 128])

    return spectrogram

# %%
def make_spec_ds(ds, batch_size=64):
    ds = ds.map(
        lambda audio, label: (get_spectrogram(audio), label),
        num_parallel_calls=tf.data.AUTOTUNE
    )
    ds = ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return ds

train_spectrogram_ds = make_spec_ds(train_dataset)
test_spectrogram_ds = make_spec_ds(test_dataset)

# Inspect a batch
for specs, labels in train_spectrogram_ds.take(1):
    print("Spectrogram batch shape:", specs.shape)
    print("Labels batch shape:", labels.shape)
    break
# Out:
# Spectrogram batch shape: (36, 124, 128, 1)
# Labels batch shape: (36,)

# %% [markdown]
# CNN

# %%
num_classes = 6
input_shape_for_model = (124, 128, 1)

model = Sequential([
    tf.keras.layers.Input(shape=input_shape_for_model),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_9 (Conv2D)               │ (None, 122, 126, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 61, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 59, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 29, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 27, 28, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 13, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 23296)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │     2,982,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,075,462 (11.73 MB)
#  Trainable params: 3,075,462 (11.73 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
EPOCHS = 5

history = model.fit(
    train_spectrogram_ds,
    validation_data=test_spectrogram_ds,
    epochs=EPOCHS,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=2,
            restore_best_weights=True,
            verbose=1
        )
    ]
)
# Out:
# Epoch 1/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.0556 - loss: 1.7906 - val_accuracy: 0.0000e+00 - val_loss: 1.8277
# Epoch 2/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.3056 - loss: 1.5469 - val_accuracy: 0.0000e+00 - val_loss: 1.9249
# Epoch 3/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.3056 - loss: 1.4214 - val_accuracy: 0.2500 - val_loss: 1.6130
# Epoch 4/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.5556 - loss: 1.3012 - val_accuracy: 0.3750 - val_loss: 1.3358
# Epoch 5/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.6389 - loss: 1.2286 - val_accuracy: 0.1250 - val_loss: 1.4500
# Restoring model weights from the end of the best epoch: 4.

# %%
def load_and_preprocess(filepath):
    # Load .wav
    audio_binary = tf.io.read_file(filepath)
    audio, sr = tf.audio.decode_wav(audio_binary)

    # Squeeze to (samples,)
    audio = tf.squeeze(audio, axis=-1)

    # Pad/trim to 16000 samples (1 sec)
    audio = audio[:16000]
    audio = tf.pad(audio, [[0, max(0, 16000 - tf.shape(audio)[0])]])

    # Back to (16000, 1)
    audio = tf.expand_dims(audio, axis=-1)

    # Convert to spectrogram
    spec = get_spectrogram(audio)

    # Add batch dim → (1, 124, 128, 1)
    spec = tf.expand_dims(spec, axis=0)
    return spec

def predict_chord(filepath):
    spec = load_and_preprocess(filepath)
    pred = model.predict(spec)
    idx = np.argmax(pred)
    confidence = float(np.max(pred))

    print("Predicted class index:", idx)
    print("Predicted label:", class_names[idx])
    print("Confidence:", confidence)

# %%
# Get the class names from the training dataset folders
class_names = train_dataset.class_names
print("Class names:", class_names)

predict_chord("/content/drive/MyDrive/guitar-dataset/IDMT-SMT-GUITAR_V2/dataset1/Fender Strat Clean Neck SC Chords/audio/3-A2-Major 01.wav")
# Out:
# Class names: ['A_major', 'A_minor', 'E_major', 'E_minor']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step
# Predicted class index: 1
# Predicted label: A_minor
# Confidence: 0.2706142067909241
